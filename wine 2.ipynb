# %%
from google.colab import drive
import numpy as np
import pandas as pd
import seaborn as sns

# %%
wine = pd.read_csv("wine.csv")

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree
from sklearn.metrics import classification_report, confusion_matrix

# %%
feature = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

x = wine.drop(columns='quality')
y = wine['quality']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5791666666666667

# %%
clf.feature_importances_
# Out:
# array([0.05492227, 0.09327424, 0.05820678, 0.09428699, 0.06097911,
#        0.07106895, 0.09184634, 0.02882414, 0.09031554, 0.14302955,
#        0.21324609])

# %%
feature_imp = pd.DataFrame({'Feature': feature, 'Importance': clf.feature_importances_})
feature_imp
# Out:
#                  Feature  Importance
# 0          fixed acidity    0.054922
# 1       volatile acidity    0.093274
# 2            citric acid    0.058207
# 3         residual sugar    0.094287
# 4              chlorides    0.060979
# 5    free sulfur dioxide    0.071069
# 6   total sulfur dioxide    0.091846
# 7                density    0.028824
# 8                     pH    0.090316
# 9              sulphates    0.143030
# 10               alcohol    0.213246

# %%
feature_imp.sort_values(by='Importance')
# Out:
#                  Feature  Importance
# 7                density    0.028824
# 0          fixed acidity    0.054922
# 2            citric acid    0.058207
# 4              chlorides    0.060979
# 5    free sulfur dioxide    0.071069
# 8                     pH    0.090316
# 6   total sulfur dioxide    0.091846
# 1       volatile acidity    0.093274
# 3         residual sugar    0.094287
# 9              sulphates    0.143030
# 10               alcohol    0.213246
